# %%
import tensorflow as tf
import numpy as np
import t3f
tf.set_random_seed(0)
np.random.seed(0)
# %matplotlib inline
import matplotlib.pyplot as plt
import metric_util as mt
import data_util as du
from t3f import shapes
from nilearn import image
from tensorflow.python.util import nest
import copy
from nilearn import plotting
from t3f import ops
import mri_draw_utils as mrd
from t3f import initializers
from t3f import approximate
from scipy import optimize 
from nilearn.masking import compute_background_mask
from nilearn.masking import compute_epi_mask
from collections import OrderedDict
import pandas as pd
from scipy import stats
from nilearn.image import math_img
from t3f import initializers
import numpy.testing as nps
from dipy.sims.voxel import add_noise
import nibabel as nib
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
subject_scan_path = du.get_full_path_subject1()
print "Subject Path: " + str(subject_scan_path)
x_true_org = mt.read_image_abs_path(subject_scan_path)
ground_truth = np.array(x_true_org.get_data()).astype('float32')
ten_ones = np.ones_like(ground_truth).astype('float32')
ten_zeros = np.zeros_like(ground_truth).astype('float32')
# Out:
# Subject Path: /work/pl/sch/analysis/data/COBRE001/swaAMAYER+cobre01_63001+M87100944+20110309at135133+RSTpre_V01_R01+CM.nii

# %%
def init_random(x):
    init = (2*np.random.random_sample(x.shape) - 1).astype('float32')
    return init

# %%
def cost_with_treshold(x, thresh = 0.000212633):
    res = tf.abs(t3f.full(x))
    zeros = tf.zeros_like(res)
    masked = tf.greater(res, thresh)
    new_tensor = tf.where(masked, t3f.full(x), zeros)
    return t3f.to_tt_tensor(new_tensor, max_tt_rank=63)

# %%
#Initialize variables

# %%
x_init = copy.deepcopy(ground_truth)
x_init_bk = copy.deepcopy(x_init)
norm_ground_x_init = np.linalg.norm(x_init)
x_init = x_init * (1./norm_ground_x_init)
#signal_w_noise = add_noise(x_init, 100000, 1, noise_type='rician')
#norm_ground_noise = np.linalg.norm(signal_w_noise)
#signal_w_noise = signal_w_noise * (1./norm_ground_noise)
#x_init = signal_w_noise.astype('float32')
#noise = np.random.normal(0, 1, x_init.shape)
#noisy = x_init + noise
#x_init = noisy.astype('float32')
tf_ten_zeros = t3f.to_tt_tensor(ten_zeros, max_tt_rank=63)
tf_ten_ones = t3f.to_tt_tensor(ten_ones, max_tt_rank=63)
# Out:
# [1, 53, 1, 1, 1] 0 (1, 53, 53)
# [1, 53, 63, 1, 1] 1 (53, 63, 63)
# [1, 53, 63, 63, 1] 2 (63, 46, 63)
# ranks: [1, 53, 63, 63, 1]
# [1, 53, 1, 1, 1] 0 (1, 53, 53)
# [1, 53, 63, 1, 1] 1 (53, 63, 63)
# [1, 53, 63, 63, 1] 2 (63, 46, 63)
# ranks: [1, 53, 63, 63, 1]

# %%
ground_truth_tf = t3f.to_tt_tensor(x_init, max_tt_rank=63)
#tf_zeros = t3f.get_variable('tf_zeros', initializer=tf_ten_zeros, trainable=False)
#tf_ones = t3f.get_variable('tf_ones', initializer=tf_ten_ones, trainable=False)
X = t3f.get_variable('X', initializer=ground_truth_tf, trainable=False)
L = t3f.get_variable('L', initializer=ground_truth_tf)
s_init = init_random(x_init)
s_init.fill(0)
s_init_tf = t3f.to_tt_tensor(s_init, max_tt_rank=63)
S = t3f.get_variable('S',initializer=s_init_tf)

#Sold = t3f.get_variable('Sold', initializer=tf_ten_zeros)
#G = t3f.get_variable('G', initializer=tf_ten_zeros)
# Out:
# [1, 53, 1, 1, 1] 0 (1, 53, 53)
# [1, 53, 63, 1, 1] 1 (53, 63, 63)
# [1, 53, 63, 63, 1] 2 (63, 46, 63)
# ranks: [1, 53, 63, 63, 1]
# [1, 53, 1, 1, 1] 0 (1, 53, 53)
# [1, 53, 63, 1, 1] 1 (53, 63, 63)
# [1, 53, 63, 63, 1] 2 (63, 46, 63)
# ranks: [1, 53, 63, 63, 1]

# %%
print S
#Initialize Gradienst
# Out:
# A Tensor Train variable of shape (53, 63, 46, 144), TT-ranks: (1, 53, 63, 63, 1)

# %%
alpha = 0.01
mu = 0.2

gradSt3f = cost_with_treshold(X - L)
rimGradS = t3f.riemannian.project(gradSt3f,S)
#train_step_tensor_s = t3f.assign(S, gradSt3f)
train_step_tensor_s = gradSt3f
gradLt3f = 1.0/(1.0 + mu)*(X - train_step_tensor_s)
rimGradL = t3f.riemannian.project(gradLt3f,L)
train_step_tensor_l = t3f.assign(L, t3f.round(L + alpha * rimGradL, max_tt_rank=63))
low_rank_update_op = t3f.assign(S, t3f.round(X - train_step_tensor_l,  max_tt_rank=63))
normGradS = t3f.frobenius_norm(rimGradS)
normGradL = t3f.frobenius_norm(rimGradL)
total_grad = rimGradS + rimGradL
total_grad_norm = t3f.frobenius_norm(total_grad)
# Out:
# [1, 53, 1, 1, 1] 0 (1, 53, 53)
# [1, 53, 63, 1, 1] 1 (53, 63, 63)
# [1, 53, 63, 63, 1] 2 (63, 46, 63)
# ranks: [1, 53, 63, 63, 1]
# Max_TT rank63
# [1, 53, 63, 63, 1]
# Max_TT rank63
# [1, 53, 63, 63, 1]

# %%
loss = 0.5 * t3f.frobenius_norm_squared(L + S - X)
normL_S = t3f.frobenius_norm(L + S - X)

# %%
def solution_stopping_criterion(ll,ss,xx):
    return (np.linalg.norm(ll + ss - xx)**2)/(np.linalg.norm(xx)**2)

# %%
def relative_convergence_error(solution, k):
    return np.linalg.norm(solution[k] - solution[k-1])/np.linalg.norm(solution[k-1])

# %%
solution_S = []
solution_L = []
solution_L_S = []

cost_S = []
cost_L = []

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for i in range (50):
    S_val, norm_gradS_val,loss_val, L_val, norm_gradL_val, normL_S_val,total_grad_norm_val,_,_,_ = sess.run([t3f.full(S), normGradS, loss, t3f.full(L), normGradL, normL_S, total_grad_norm, train_step_tensor_s.op, train_step_tensor_l.op, low_rank_update_op.op])
    #loss_val, L_val, norm_gradL_val, normL_S_val,_ = sess.run([loss, t3f.full(L), normGradL, normL_S, train_step_tensor_l.op])
    print "Iteration#: " + str(i) + "; loss: " + str(loss_val) + "; norm_gradL: " + str(norm_gradL_val) + "; norm_gradS: " + str(norm_gradS_val)
    print "Residual Norm: " + str(normL_S_val)
    print "Gradient Norm: " + str(total_grad_norm_val)
    solution_S.append(S_val)
    solution_L.append(L_val)
    solution_L_S.append(normL_S_val)
    
    solution_tolerance = solution_stopping_criterion(L_val, S_val, x_init)
    
    if i >= 1:
        cost_s_sol = relative_convergence_error(solution_S, i)
        cost_l_sol = relative_convergence_error(solution_L, i)
        cost_ls_sol = relative_convergence_error(solution_L_S, i)
        print "S Relative Error: " + str(cost_s_sol) + "; L Relative Error: " + str(cost_l_sol)
        print "Total Solution Relative Error: " + str(cost_ls_sol)
        
    print "Solution Tolerance: " + str(solution_tolerance)
# Out:
# Iteration#: 0; loss: 2.7200634e-11; norm_gradL: 0.83348346; norm_gradS: 0.0031622776
# Residual Norm: 0.0031622862
# Gradient Norm: 0.8334858
# Solution Tolerance: 8.990767438752686e-06
# Iteration#: 1; loss: 1.6292691e-10; norm_gradL: 0.8334803; norm_gradS: 0.0031622776
# Residual Norm: 0.003162329
# Gradient Norm: 0.8334822
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in float_scalars
# S Relative Error: inf; L Relative Error: 0.0083334595
# Total Solution Relative Error: 1.3547426e-05
# Solution Tolerance: 8.990800948204528e-06
# Iteration#: 2; loss: 1.7969906e-10; norm_gradL: 0.8334809; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623344
# Gradient Norm: 0.8334822
# S Relative Error: 0.99927515; L Relative Error: 0.008264381
# Total Solution Relative Error: 1.6934052e-06
# Solution Tolerance: 8.990802344433043e-06
# Iteration#: 3; loss: 1.8493013e-10; norm_gradL: 0.8334828; norm_gradS: 0.0031622776
# Residual Norm: 0.003162336
# Gradient Norm: 0.8334822
# S Relative Error: 0.4997863; L Relative Error: 0.008196671
# Total Solution Relative Error: 5.1538336e-07
# Solution Tolerance: 8.990812118035686e-06
# Iteration#: 4; loss: 1.8963638e-10; norm_gradL: 0.8334808; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623377
# Gradient Norm: 0.83348244
# S Relative Error: 0.3332506; L Relative Error: 0.008129916
# Total Solution Relative Error: 5.153831e-07
# Solution Tolerance: 8.990820495413608e-06
# Iteration#: 5; loss: 2.465939e-10; norm_gradL: 0.83348113; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623556
# Gradient Norm: 0.8334824
# S Relative Error: 0.24992993; L Relative Error: 0.0080649955
# Total Solution Relative Error: 5.669211e-06
# Solution Tolerance: 8.990799551976121e-06
# Iteration#: 6; loss: 2.0673076e-10; norm_gradL: 0.83348185; norm_gradS: 0.0031622776
# Residual Norm: 0.003162343
# Gradient Norm: 0.8334824
# S Relative Error: 0.1999737; L Relative Error: 0.008000239
# Total Solution Relative Error: 3.975788e-06
# Solution Tolerance: 8.990809325577246e-06
# Iteration#: 7; loss: 1.8283425e-10; norm_gradL: 0.8334807; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623354
# Gradient Norm: 0.8334827
# S Relative Error: 0.16664758; L Relative Error: 0.00793726
# Total Solution Relative Error: 2.4296578e-06
# Solution Tolerance: 8.990800948204528e-06
# Iteration#: 8; loss: 2.3359392e-10; norm_gradL: 0.83348083; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623514
# Gradient Norm: 0.833482
# S Relative Error: 0.14284156; L Relative Error: 0.007874707
# Total Solution Relative Error: 5.080206e-06
# Solution Tolerance: 8.990798155747822e-06
# Iteration#: 9; loss: 3.002184e-10; norm_gradL: 0.83348006; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623726
# Gradient Norm: 0.8334824
# S Relative Error: 0.12499725; L Relative Error: 0.0078129545
# Total Solution Relative Error: 6.6999473e-06
# Solution Tolerance: 8.990810721806412e-06
# Iteration#: 10; loss: 2.5491537e-10; norm_gradL: 0.83348054; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623582
# Gradient Norm: 0.8334827
# S Relative Error: 0.1111013; L Relative Error: 0.0077523724
# Total Solution Relative Error: 4.564769e-06
# Solution Tolerance: 8.990813514265067e-06
# Iteration#: 11; loss: 2.2310394e-10; norm_gradL: 0.8334813; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623482
# Gradient Norm: 0.8334821
# S Relative Error: 0.09998039; L Relative Error: 0.0076924847
# Total Solution Relative Error: 3.1659024e-06
# Solution Tolerance: 8.990814910494558e-06
# Iteration#: 12; loss: 1.8787147e-10; norm_gradL: 0.8334817; norm_gradS: 0.0031622776
# Residual Norm: 0.003162337
# Gradient Norm: 0.8334825
# S Relative Error: 0.09089856; L Relative Error: 0.007633578
# Total Solution Relative Error: 3.534042e-06
# Solution Tolerance: 8.990814910494558e-06
# Iteration#: 13; loss: 2.8882613e-10; norm_gradL: 0.8334802; norm_gradS: 0.0031622776
# Residual Norm: 0.003162369
# Gradient Norm: 0.8334821
# S Relative Error: 0.08332413; L Relative Error: 0.0075758044
# Total Solution Relative Error: 1.008678e-05
# Solution Tolerance: 8.990807929348188e-06
# Iteration#: 14; loss: 2.5843339e-10; norm_gradL: 0.8334802; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623594
# Gradient Norm: 0.8334821
# S Relative Error: 0.0769169; L Relative Error: 0.00751895
# Total Solution Relative Error: 3.0186409e-06
# Solution Tolerance: 8.990816306724158e-06
# Iteration#: 15; loss: 2.4206329e-10; norm_gradL: 0.8334809; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623542
# Gradient Norm: 0.8334822
# S Relative Error: 0.07141565; L Relative Error: 0.007462428
# Total Solution Relative Error: 1.6197635e-06
# Solution Tolerance: 8.990814910494558e-06
# Iteration#: 16; loss: 2.5686478e-10; norm_gradL: 0.8334807; norm_gradS: 0.0031622776
# Residual Norm: 0.003162359
# Gradient Norm: 0.833482
# S Relative Error: 0.06665297; L Relative Error: 0.007407196
# Total Solution Relative Error: 1.4725147e-06
# Solution Tolerance: 8.990813514265067e-06
# Iteration#: 17; loss: 2.5716898e-10; norm_gradL: 0.83348113; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623591
# Gradient Norm: 0.8334818
# S Relative Error: 0.06249138; L Relative Error: 0.007352553
# Total Solution Relative Error: 7.362562e-08
# Solution Tolerance: 8.990813514265067e-06
# Iteration#: 18; loss: 2.7754296e-10; norm_gradL: 0.83348113; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623654
# Gradient Norm: 0.8334823
# S Relative Error: 0.058818653; L Relative Error: 0.007299153
# Total Solution Relative Error: 1.9878917e-06
# Solution Tolerance: 8.990816306724158e-06
# Iteration#: 19; loss: 3.109567e-10; norm_gradL: 0.8334809; norm_gradS: 0.0031622776
# Residual Norm: 0.003162376
# Gradient Norm: 0.8334825
# S Relative Error: 0.055550765; L Relative Error: 0.0072461776
# Total Solution Relative Error: 3.3131462e-06
# Solution Tolerance: 8.990819099183683e-06
# Iteration#: 20; loss: 2.78623e-10; norm_gradL: 0.8334814; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623659
# Gradient Norm: 0.83348256
# S Relative Error: 0.05262712; L Relative Error: 0.007194127
# Total Solution Relative Error: 3.165885e-06
# Solution Tolerance: 8.990820495413608e-06
# Iteration#: 21; loss: 2.3745572e-10; norm_gradL: 0.8334804; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623526
# Gradient Norm: 0.8334821
# S Relative Error: 0.049996376; L Relative Error: 0.007142997
# Total Solution Relative Error: 4.1966514e-06
# Solution Tolerance: 8.99082189164364e-06
# Iteration#: 22; loss: 2.2368009e-10; norm_gradL: 0.83348036; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623484
# Gradient Norm: 0.83348256
# S Relative Error: 0.047615003; L Relative Error: 0.0070922626
# Total Solution Relative Error: 1.3252638e-06
# Solution Tolerance: 8.990834457718815e-06
# Iteration#: 23; loss: 2.3043639e-10; norm_gradL: 0.8334799; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623505
# Gradient Norm: 0.8334825
# S Relative Error: 0.04544992; L Relative Error: 0.0070422026
# Total Solution Relative Error: 6.6263283e-07
# Solution Tolerance: 8.990819099183683e-06
# Iteration#: 24; loss: 2.7561153e-10; norm_gradL: 0.8334809; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623647
# Gradient Norm: 0.83348286
# S Relative Error: 0.043478873; L Relative Error: 0.006993117
# Total Solution Relative Error: 4.491175e-06
# Solution Tolerance: 8.990830269026115e-06
# Iteration#: 25; loss: 2.1222535e-10; norm_gradL: 0.8334802; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623447
# Gradient Norm: 0.83348256
# S Relative Error: 0.041664284; L Relative Error: 0.006944235
# Total Solution Relative Error: 6.331792e-06
# Solution Tolerance: 8.99082608033439e-06
# Iteration#: 26; loss: 2.440492e-10; norm_gradL: 0.8334796; norm_gradS: 0.0031622776
# Residual Norm: 0.003162355
# Gradient Norm: 0.8334824
# S Relative Error: 0.039995197; L Relative Error: 0.006896173
# Total Solution Relative Error: 3.239542e-06
# Solution Tolerance: 8.990824684104031e-06
# Iteration#: 27; loss: 2.4143001e-10; norm_gradL: 0.83347994; norm_gradS: 0.0031622776
# Residual Norm: 0.003162354
# Gradient Norm: 0.8334828
# S Relative Error: 0.038458876; L Relative Error: 0.0068490184
# Total Solution Relative Error: 2.9450285e-07
# Solution Tolerance: 8.99082608033439e-06
# Iteration#: 28; loss: 3.0992187e-10; norm_gradL: 0.8334803; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623757
# Gradient Norm: 0.8334825
# S Relative Error: 0.037033588; L Relative Error: 0.006802602
# Total Solution Relative Error: 6.8471936e-06
# Solution Tolerance: 8.990833061487808e-06
# Iteration#: 29; loss: 2.7933e-10; norm_gradL: 0.83348036; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623659
# Gradient Norm: 0.8334825
# S Relative Error: 0.03571242; L Relative Error: 0.0067567867
# Total Solution Relative Error: 3.0922597e-06
# Solution Tolerance: 8.990824684104031e-06
# Iteration#: 30; loss: 2.9066186e-10; norm_gradL: 0.8334804; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623696
# Gradient Norm: 0.8334824
# S Relative Error: 0.03448031; L Relative Error: 0.006711257
# Total Solution Relative Error: 1.1780073e-06
# Solution Tolerance: 8.990842835107145e-06
# Iteration#: 31; loss: 2.737946e-10; norm_gradL: 0.83348113; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623642
# Gradient Norm: 0.83348244
# S Relative Error: 0.03332889; L Relative Error: 0.006666427
# Total Solution Relative Error: 1.6933836e-06
# Solution Tolerance: 8.990837250181159e-06
# Iteration#: 32; loss: 2.5942332e-10; norm_gradL: 0.8334808; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623596
# Gradient Norm: 0.8334822
# S Relative Error: 0.032258328; L Relative Error: 0.0066223764
# Total Solution Relative Error: 1.47251e-06
# Solution Tolerance: 8.990838646412493e-06
# Iteration#: 33; loss: 2.1783764e-10; norm_gradL: 0.83348066; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623465
# Gradient Norm: 0.83348215
# S Relative Error: 0.0312475; L Relative Error: 0.006578881
# Total Solution Relative Error: 4.123034e-06
# Solution Tolerance: 8.99082608033439e-06
# Iteration#: 34; loss: 1.8742295e-10; norm_gradL: 0.8334807; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623368
# Gradient Norm: 0.8334822
# S Relative Error: 0.030302497; L Relative Error: 0.0065357327
# Total Solution Relative Error: 3.0922881e-06
# Solution Tolerance: 8.990833061487808e-06
# Iteration#: 35; loss: 2.3321164e-10; norm_gradL: 0.8334802; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623514
# Gradient Norm: 0.8334824
# S Relative Error: 0.02941232; L Relative Error: 0.0064931596
# Total Solution Relative Error: 4.6384466e-06
# Solution Tolerance: 8.990847023802773e-06
# Iteration#: 36; loss: 2.3727145e-10; norm_gradL: 0.8334797; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623526
# Gradient Norm: 0.83348215
# S Relative Error: 0.028569559; L Relative Error: 0.0064510433
# Total Solution Relative Error: 3.6812898e-07
# Solution Tolerance: 8.990849816267068e-06
# Iteration#: 37; loss: 2.3398106e-10; norm_gradL: 0.83348; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623517
# Gradient Norm: 0.8334822
# S Relative Error: 0.027773654; L Relative Error: 0.0064099412
# Total Solution Relative Error: 2.9450308e-07
# Solution Tolerance: 8.990842835107145e-06
# Iteration#: 38; loss: 1.9435852e-10; norm_gradL: 0.8334802; norm_gradS: 0.0031622776
# Residual Norm: 0.003162339
# Gradient Norm: 0.83348244
# S Relative Error: 0.02702565; L Relative Error: 0.0063693123
# Total Solution Relative Error: 3.975793e-06
# Solution Tolerance: 8.990835853949933e-06
# Iteration#: 39; loss: 2.1968193e-10; norm_gradL: 0.8334799; norm_gradS: 0.0031622776
# Residual Norm: 0.003162347
# Gradient Norm: 0.8334824
# S Relative Error: 0.02631735; L Relative Error: 0.0063291853
# Total Solution Relative Error: 2.5032869e-06
# Solution Tolerance: 8.990859589895513e-06
# Iteration#: 40; loss: 2.5415148e-10; norm_gradL: 0.8334804; norm_gradS: 0.0031622776
# Residual Norm: 0.003162358
# Gradient Norm: 0.8334825
# S Relative Error: 0.025639616; L Relative Error: 0.006289235
# Total Solution Relative Error: 3.4604172e-06
# Solution Tolerance: 8.990847023802773e-06
# Iteration#: 41; loss: 2.523305e-10; norm_gradL: 0.83348083; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623575
# Gradient Norm: 0.8334821
# S Relative Error: 0.024998263; L Relative Error: 0.006249925
# Total Solution Relative Error: 1.4725128e-07
# Solution Tolerance: 8.990844231338914e-06
# Iteration#: 42; loss: 2.0083607e-10; norm_gradL: 0.83348054; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623412
# Gradient Norm: 0.83348256
# S Relative Error: 0.024387928; L Relative Error: 0.0062110657
# Total Solution Relative Error: 5.153796e-06
# Solution Tolerance: 8.990842835107145e-06
# Iteration#: 43; loss: 2.2610257e-10; norm_gradL: 0.83348006; norm_gradS: 0.0031622776
# Residual Norm: 0.003162349
# Gradient Norm: 0.83348215
# S Relative Error: 0.023809033; L Relative Error: 0.006172706
# Total Solution Relative Error: 2.5032853e-06
# Solution Tolerance: 8.990852608731796e-06
# Iteration#: 44; loss: 2.5861155e-10; norm_gradL: 0.8334805; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623594
# Gradient Norm: 0.8334821
# S Relative Error: 0.023255654; L Relative Error: 0.006135006
# Total Solution Relative Error: 3.2395374e-06
# Solution Tolerance: 8.990841438875486e-06
# Iteration#: 45; loss: 2.3856297e-10; norm_gradL: 0.83348006; norm_gradS: 0.0031622776
# Residual Norm: 0.003162353
# Gradient Norm: 0.8334822
# S Relative Error: 0.02272654; L Relative Error: 0.0060975356
# Total Solution Relative Error: 1.9878914e-06
# Solution Tolerance: 8.990840042643935e-06
# Iteration#: 46; loss: 2.3035841e-10; norm_gradL: 0.83348; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623505
# Gradient Norm: 0.8334827
# S Relative Error: 0.022223778; L Relative Error: 0.0060606194
# Total Solution Relative Error: 8.098833e-07
# Solution Tolerance: 8.990847023802773e-06
# Iteration#: 47; loss: 2.687039e-10; norm_gradL: 0.8334802; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623626
# Gradient Norm: 0.8334823
# S Relative Error: 0.021739481; L Relative Error: 0.006023873
# Total Solution Relative Error: 3.8285425e-06
# Solution Tolerance: 8.990851212499377e-06
# Iteration#: 48; loss: 2.4485614e-10; norm_gradL: 0.8334801; norm_gradS: 0.0031622776
# Residual Norm: 0.003162355
# Gradient Norm: 0.83348256
# S Relative Error: 0.021275174; L Relative Error: 0.0059877397
# Total Solution Relative Error: 2.4296428e-06
# Solution Tolerance: 8.990842835107145e-06
# Iteration#: 49; loss: 2.642358e-10; norm_gradL: 0.8334799; norm_gradS: 0.0031622776
# Residual Norm: 0.0031623612
# Gradient Norm: 0.83348274
# S Relative Error: 0.020834057; L Relative Error: 0.0059519345
# Total Solution Relative Error: 1.9878944e-06
# Solution Tolerance: 8.99086098612858e-06

# %%
G = x_init - L_val - S_val

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, x_init)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='jet', cut_coords=None)

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, x_init_bk)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='jet', cut_coords=None)

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, L_val)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='jet', cut_coords=None)

# %%
diff_img =  x_init - L_val

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, diff_img)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='gray', cut_coords=None)

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, S_val)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='jet', cut_coords=None)

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, G)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='jet', cut_coords=None)

# %%
solution_tolerance = solution_stopping_criterion(L_val, S_val, x_init)

# %%
solution_tolerance
# Out:
# 8.99086098612858e-06

# %%
total = S_val + L_val + G

# %%
nps.assert_allclose(total, x_init, rtol=1e-4, atol=0)

# %%
from skimage.util import random_noise

# %%
noisy = random_noise(x_init, var=0.01)

# %%
noise = np.random.normal(0, 1, x_init.shape)

# %%
noisy = x_init + noise

# %%
from dipy.sims.voxel import add_noise
from dipy.denoise.noise_estimate import estimate_sigma

# %%
sigma = estimate_sigma(noisy, N=1)

# %%
from dipy.denoise.nlmeans import nlmeans
den = nlmeans(noisy, sigma=sigma, patch_radius= 1, block_radius = 1, rician= False)

# %%
mask_img = compute_epi_mask(x_true_org)
mask_img_data = np.array(mask_img.get_data())

# %%
import noise_util

# %%
from dipy.sims.voxel import add_noise

# %%
x_init_copy = copy.deepcopy(x_init)

# %%
signal_w_noise = add_noise(x_init_copy, 100000, 1, noise_type='rician')
norm_ground_noise = np.linalg.norm(signal_w_noise)
signal_w_noise = signal_w_noise * (1./norm_ground_noise)
x_hat_img = mt.reconstruct_image_affine(x_true_org, signal_w_noise)
x_hat = image.index_img(x_hat_img,1)
recovered_image = plotting.plot_epi(x_hat, bg_img=None,black_bg=True, cmap='jet', cut_coords=None)

# %%
noise_img = mt.reconstruct_image_affine(x_true_org, x_init)

# %%
nib.save(noise_img, 'noise_img.nii')

# %%
#dipy.sims.voxel.add_noise(signal, snr, S0, noise_type='rician')

recovered_image = mt.reconstruct_image_affine(x_true_org, L_val)
nib.save(recovered_image, 'low-rank-img.nii')

# %%
from nipype.algorithms import confounds as nac

# %%
tsnr = nac.TSNR()
tsnr.inputs.in_file = 'low-rank-img.nii'
res = tsnr.run()

# %%
tsnr_path = 'tsnr.nii.gz'
tsnr_image = mt.read_image_abs_path(tsnr_path)
tsnr_image_data = np.array(tsnr_image.get_data())

# %%
tsnr_img = mt.reconstruct_image_affine(x_true_org, tsnr_image_data)
recovered_image = plotting.plot_epi(tsnr_img, bg_img=None,black_bg=True, display_mode='z', cmap='jet', cut_coords = 3)

# %%
mean_path = 'mean.nii.gz'
mean_image = mt.read_image_abs_path(mean_path)
mean_image_data = np.array(mean_image.get_data())

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, mean_image_data)
recovered_image = plotting.plot_epi(x_hat_img, bg_img=None,black_bg=True, display_mode='z', cmap='jet', cut_coords = 3)

# %%
stdev_path = 'stdev.nii.gz'
stdev_image = mt.read_image_abs_path(stdev_path)
stdev_image_data = np.array(stdev_image.get_data())

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, stdev_image_data)
recovered_image = plotting.plot_epi(x_hat_img, bg_img=None,black_bg=True, display_mode='z', cmap='jet', cut_coords = 3)

# %%
tsnr = nac.TSNR()
tsnr.inputs.in_file = subject_scan_path
res = tsnr.run()

# %%
stdev_path = 'stdev.nii.gz'
stdev_image = mt.read_image_abs_path(stdev_path)
stdev_image_data = np.array(stdev_image.get_data())

# %%
x_hat_img = mt.reconstruct_image_affine(x_true_org, stdev_image_data)
recovered_image = plotting.plot_epi(x_hat_img, bg_img=None,black_bg=True, display_mode='z', cmap='jet', cut_coords = 3)

# %%
mask_img = compute_epi_mask(x_true_org)

# %%
nib.save(mask_img, 'epi_mask.nii')

# %%
dvars = nac.ComputeDVARS()

# %%
dvars.inputs.in_file = subject_scan_path
dvars.inputs.in_mask = 'epi_mask.nii'
dvars.inputs.save_all = True
dvars.inputs.save_plot = True
dvars.inputs.figformat = 'pdf'
dvars.run()

# %%
dvars.inputs.in_file = 'low-rank-img.nii'
dvars.inputs.in_mask = 'epi_mask.nii'
dvars.inputs.save_all = True
dvars.inputs.save_plot = True
dvars.inputs.figformat = 'pdf'
dvars.run()
# Out:
# /usr/local/lib/python2.7/site-packages/nitime/utils.py:980: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   complex_result = (np.issubdtype(in1.dtype, np.complex) or
# /usr/local/lib/python2.7/site-packages/nitime/utils.py:981: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   np.issubdtype(in2.dtype, np.complex))

# %%
comp_corr = nac.CompCor()
comp_corr.inputs.realigned_file = subject_scan_path
comp_corr.run()
